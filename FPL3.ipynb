# %%
import matplotlib.pyplot as plt  
import pandas as pd  
import json
import plotly
plotly.tools.set_credentials_file(username='sephusx', api_key='YVMOomXql8iwhQ3NkJYR')

# (*) To communicate with Plotly's server, sign in with credentials file
import plotly.plotly as py  

# (*) Useful Python/Plotly tools
import plotly.tools as tls   

# (*) Graph objects to piece together plots
from plotly.graph_objs import *

import numpy as np  # (*) numpy for math functions and arrays

# import urllib2
import pandas as pd
# %matplotlib inline

import requests

response = requests.get(
#     'https://fantasy.premierleague.com/drf/element-summary/176'
#                         'https://fantasy.premierleague.com/drf/entry/1377859/event/2/picks'
                        'https://fantasy.premierleague.com/drf/entry/1377859/history'
                         )
data = response.json()
lst= data.get('history')


response = requests.get(
#     'https://fantasy.premierleague.com/drf/element-summary/176'
#                         'https://fantasy.premierleague.com/drf/entry/1377859/event/2/picks'
                        'https://fantasy.premierleague.com/drf/entry/2580286/history'
                         )
data2 = response.json()
lst2= data2.get('history')


response = requests.get(
#     'https://fantasy.premierleague.com/drf/element-summary/176'
#                         'https://fantasy.premierleague.com/drf/entry/1377859/event/2/picks'
                        'https://fantasy.premierleague.com/drf/entry/4422822/history'
                         )
data3 = response.json()
lst3= data3.get('history')


response = requests.get(
#     'https://fantasy.premierleague.com/drf/element-summary/176'
#                         'https://fantasy.premierleague.com/drf/entry/1377859/event/2/picks'
                        'https://fantasy.premierleague.com/drf/entry/1732497/history'
                         )
data4 = response.json()
lst4= data4.get('history')

lst_total=lst+lst2+lst3+lst4


labels = ('bank','entry','event','event_transfers','event_transfers_cost', 'id', 'movement',  'overall_rank',  'points',
  'points_on_bench','rank','rank_sort','targets','total_points','value')

df= pd.DataFrame.from_records(lst_total,columns=labels)


def plot_mpl_fig():

  
    # Read the data into a pandas DataFrame.    
    gender_degree_data = pd.read_csv("http://www.randalolson.com/wp-content/uploads/percent-bachelors-degrees-women-usa.csv")    

    # These are the "Tableau 20" colors as RGB.    
    tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),    
                 (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),    
                 (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),    
                 (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),    
                 (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]    

    # Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.    
    for i in range(len(tableau20)):    
        r, g, b = tableau20[i]    
        tableau20[i] = (r / 255., g / 255., b / 255.)    

    # You typically want your plot to be ~1.33x wider than tall. This plot is a rare    
    # exception because of the number of lines being plotted on it.    
    # Common sizes: (10, 7.5) and (12, 9)    
    plt.figure(figsize=(12, 14))    

    # Remove the plot frame lines. They are unnecessary chartjunk.    
    ax = plt.subplot(111)    
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)    
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.get_xaxis().tick_bottom()    
    ax.get_yaxis().tick_left()  

    plt.ylim(0, 400)    
    plt.xlim(0, 7)  
    plt.yticks(fontsize=14)  
    plt.xticks(fontsize=14) 
    for y in range(0, 400, 10):    
        plt.plot(range(0, 400), [y] * len(range(0, 400)), "--", lw=0.5, color="black", alpha=0.3)   

    plt.tick_params(axis="both", which="both", bottom="off", top="off",    
                    labelbottom="on", left="off", right="off", labelleft="on")
    
    event=[1, 2, 3, 4, 5, 6]
    majors = [lst,lst2,lst3,lst4]
    
    def set_color(row):
        if row["entry"] == 4422822:
            return "Ciccio"
        elif row["entry"] == 1377859:
            return "Anto"
        elif row["entry"] == 1732497:
            return "Viados"
        elif row["entry"] == 2580286:
            return "Nico"
        else:
            return "green"

     
    df= pd.DataFrame.from_records(lst,columns=labels)
    df = df.assign(name=df.apply(set_color, axis=1))

   
    for rank, column in enumerate(majors): 
        df= pd.DataFrame.from_records(column,columns=labels)
        df = df.assign(name=df.apply(set_color, axis=1))
        plt.plot(df['event'].values,df['total_points'].values,lw=2.5, color=tableau20[rank])
        plt.text(df['event'].max(), df['total_points'].max(), df['name'].iloc[0], fontsize=14, color=tableau20[rank])
        

#         plt.plot(event,df['total_points'][df['entry'] == column].values,lw=2.5, color=tableau20[rank])
#             plt.text(df['event'].max(), df['total_points'].max(), df['entry'], fontsize=14, color=tableau20[rank])    


# Plot it!
plot_mpl_fig()
mpl_fig1 = plt.gcf()

py.iplot_mpl(mpl_fig1, strip_style=False, filename='F_Stats')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~sephusx/2.embed" height="525px" width="100%"></iframe>
