# %%
import json
# import urllib2
import pandas as pd
# %matplotlib inline

# %%
import requests

response = requests.get(
#     'https://fantasy.premierleague.com/drf/element-summary/176'
#                         'https://fantasy.premierleague.com/drf/entry/1377859/event/2/picks'
                        'https://fantasy.premierleague.com/drf/entry/1377859/history'
                         )
data = response.json()

# %%
data


lst= data.get('history')
# for key,value in data.items():
#     print(value,key)

# new_data=data.get('entry_history')
# new_data.get('points')

# data.get('entry_history').get('points')
# for l in lst:
#     d=l
#     print(d.get('points'))  
#     print(d.get('event'))  
#     print(d.get('entry'))  
    
labels = ('bank','entry','event','event_transfers','event_transfers_cost', 'id', 'movement',  'overall_rank',  'points',
  'points_on_bench','rank','rank_sort','targets','total_points','value')

df= pd.DataFrame.from_records(lst,columns=labels)

# %%
df.plot.line(x='event',y='total_points')

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
sns.pointplot(x="event", y="total_points", hue="entry",data=df);

# %%
lst
# Out:
# [{'bank': 0,
#   'entry': 1377859,
#   'event': 1,
#   'event_transfers': 0,
#   'event_transfers_cost': 0,
#   'id': 1377859,
#   'movement': 'new',
#   'overall_rank': 877855,
#   'points': 70,
#   'points_on_bench': 5,
#   'rank': 877855,
#   'rank_sort': 907848,
#   'targets': None,
#   'total_points': 70,
#   'value': 1000},
#  {'bank': 20,
#   'entry': 1377859,
#   'event': 2,
#   'event_transfers': 1,
#   'event_transfers_cost': 0,
#   'id': 5309959,
#   'movement': 'up',
#   'overall_rank': 566845,
#   'points': 55,
#   'points_on_bench': 6,
#   'rank': 908143,
#   'rank_sort': 919627,
#   'targets': None,
#   'total_points': 125,
#   'value': 1002},
#  {'bank': 20,
#   'entry': 1377859,
#   'event': 3,
#   'event_transfers': 0,
#   'event_transfers_cost': 0,
#   'id': 9831874,
#   'movement': 'down',
#   'overall_rank': 938147,
#   'points': 37,
#   'points_on_bench': 12,
#   'rank': 3200938,
#   'rank_sort': 3220845,
#   'targets': None,
#   'total_points': 162,
# ...

# %%
response = requests.get(
#     'https://fantasy.premierleague.com/drf/element-summary/176'
#                         'https://fantasy.premierleague.com/drf/entry/1377859/event/2/picks'
                        'https://fantasy.premierleague.com/drf/entry/1377859/history'
                         )
data = response.json()
lst= data.get('history')


response = requests.get(
#     'https://fantasy.premierleague.com/drf/element-summary/176'
#                         'https://fantasy.premierleague.com/drf/entry/1377859/event/2/picks'
                        'https://fantasy.premierleague.com/drf/entry/2580286/history'
                         )
data2 = response.json()
lst2= data2.get('history')


response = requests.get(
#     'https://fantasy.premierleague.com/drf/element-summary/176'
#                         'https://fantasy.premierleague.com/drf/entry/1377859/event/2/picks'
                        'https://fantasy.premierleague.com/drf/entry/4422822/history'
                         )
data3 = response.json()
lst3= data3.get('history')


response = requests.get(
#     'https://fantasy.premierleague.com/drf/element-summary/176'
#                         'https://fantasy.premierleague.com/drf/entry/1377859/event/2/picks'
                        'https://fantasy.premierleague.com/drf/entry/1732497/history'
                         )
data4 = response.json()
lst4= data4.get('history')

lst_total=lst+lst2+lst3+lst4

# 1732497

# %%
df= pd.DataFrame.from_records(lst_total,columns=labels)

# %%
sns.pointplot(x="event", y="total_points", hue="entry",markers='o',dodge=True,data=df,scale =0.7,join=True);

# %%
df.plot.line(x='event',y='total_points')

# %%
import matplotlib.pyplot as plt  
import pandas as pd  
  
# Read the data into a pandas DataFrame.    
gender_degree_data = pd.read_csv("http://www.randalolson.com/wp-content/uploads/percent-bachelors-degrees-women-usa.csv")    
  
# These are the "Tableau 20" colors as RGB.    
tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),    
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),    
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),    
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),    
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]    
  
# Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.    
for i in range(len(tableau20)):    
    r, g, b = tableau20[i]    
    tableau20[i] = (r / 255., g / 255., b / 255.)    
  
# You typically want your plot to be ~1.33x wider than tall. This plot is a rare    
# exception because of the number of lines being plotted on it.    
# Common sizes: (10, 7.5) and (12, 9)    
plt.figure(figsize=(12, 14))    
  
# Remove the plot frame lines. They are unnecessary chartjunk.    
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)    
  
# Ensure that the axis ticks only show up on the bottom and left of the plot.    
# Ticks on the right and top of the plot are generally unnecessary chartjunk.    
ax.get_xaxis().tick_bottom()    
ax.get_yaxis().tick_left()    
  
# Limit the range of the plot to only where the data is.    
# Avoid unnecessary whitespace.    
plt.ylim(0, 90)    
plt.xlim(1968, 2014)    
  
# Make sure your axis ticks are large enough to be easily read.    
# You don't want your viewers squinting to read your plot.    
plt.yticks(range(0, 91, 10), [str(x) + "%" for x in range(0, 91, 10)], fontsize=14)    
plt.xticks(fontsize=14)    
  
# Provide tick lines across the plot to help your viewers trace along    
# the axis ticks. Make sure that the lines are light and small so they    
# don't obscure the primary data lines.    
for y in range(10, 91, 10):    
    plt.plot(range(1968, 2012), [y] * len(range(1968, 2012)), "--", lw=0.5, color="black", alpha=0.3)    
  
# Remove the tick marks; they are unnecessary with the tick lines we just plotted.    
plt.tick_params(axis="both", which="both", bottom="off", top="off",    
                labelbottom="on", left="off", right="off", labelleft="on")    
  
# Now that the plot is prepared, it's time to actually plot the data!    
# Note that I plotted the majors in order of the highest % in the final year.    
majors = ['Health Professions', 'Public Administration', 'Education', 'Psychology',    
          'Foreign Languages', 'English', 'Communications\nand Journalism',    
          'Art and Performance', 'Biology', 'Agriculture',    
          'Social Sciences and History', 'Business', 'Math and Statistics',    
          'Architecture', 'Physical Sciences', 'Computer Science',    
          'Engineering']    
  
for rank, column in enumerate(majors):    
    # Plot each line separately with its own color, using the Tableau 20    
    # color set in order. 
    print(gender_degree_data.Year.values)
    plt.plot(gender_degree_data.Year.values,    
            gender_degree_data[column.replace("\n", " ")].values,    
            lw=2.5, color=tableau20[rank])
# Out:
# [1970 1971 1972 1973 1974 1975 1976 1977 1978 1979 1980 1981 1982 1983 1984
#  1985 1986 1987 1988 1989 1990 1991 1992 1993 1994 1995 1996 1997 1998 1999
#  2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011]
# [1970 1971 1972 1973 1974 1975 1976 1977 1978 1979 1980 1981 1982 1983 1984
#  1985 1986 1987 1988 1989 1990 1991 1992 1993 1994 1995 1996 1997 1998 1999
#  2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011]
# [1970 1971 1972 1973 1974 1975 1976 1977 1978 1979 1980 1981 1982 1983 1984
#  1985 1986 1987 1988 1989 1990 1991 1992 1993 1994 1995 1996 1997 1998 1999
#  2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011]
# [1970 1971 1972 1973 1974 1975 1976 1977 1978 1979 1980 1981 1982 1983 1984
#  1985 1986 1987 1988 1989 1990 1991 1992 1993 1994 1995 1996 1997 1998 1999
#  2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011]
# [1970 1971 1972 1973 1974 1975 1976 1977 1978 1979 1980 1981 1982 1983 1984
# ...
